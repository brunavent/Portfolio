# %% [markdown]
# <a href="https://colab.research.google.com/github/brunavent/portfolio/blob/master/Panorama_do_COVID_19_no_Brasil_e_no_Mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Panorama do COVID-19 no Brasil e no Mundo
#
# A **COVID-19** é uma doença infecciosa causada pelo novo coronavírus (*SARS-CoV-2*) e tem como principais sintomas *febre*, *cansaço* e *tosse seca*.
#
# Alguns pacientes podem apresentar dores, congestão nasal, dor de cabeça, conjuntivite, dor de garganta, diarreia, perda de paladar ou olfato, erupção cutânea na pele ou descoloração dos dedos das mãos ou dos pés. Esses sintomas geralmente são leves e começam gradualmente. Algumas pessoas são infectadas, mas apresentam apenas sintomas muito leves.
#
# <center><img width="50%" src="https://raw.githubusercontent.com/brunavent/template_temp/master/20944956.jpg"></center>
#
#
# A maioria das pessoas (cerca de 80%) se recupera da doença sem precisar de tratamento hospitalar.
# **Uma em cada seis pessoas infectadas por COVID-19 fica gravemente doente e desenvolve dificuldade de respirar**.
#
# As pessoas idosas e as que têm outras condições de saúde como *pressão alta*, *problemas cardíacos* e do *pulmão*, *diabetes* ou *câncer*, têm maior risco de ficarem gravemente doentes. No entanto, qualquer pessoa pode pegar a COVID-19 e ficar gravemente doente.
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19 no Brasil, irei realizar uma análise sobre os dados públicos da doença.

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados utilizados foram obtidos a partir do repositório do [OWID](https://github.com/owid/covid-19-data/tree/master/public/data) sobre COVID.
#
# O dataset utilizado para análise será o `owid-covid-data.csv` - Dados sobre o COVID-19 (coronavírus) por Our World in Data.
#
# Esse dataset nos trará dados sobre casos confirmados, mortes, testes, vacinas e hospitalizações, assim como outras variáveis de potencial interesse.
#
# Por se tratar de uma doença e de uam situação nova, as lacunas de informação e conhecimento ainda são muito grandes: taxas de letalidade, potencial de transmissão, tratamento, existência de outros efeitos ou sequelas no organismo dos que foram infectados, todas essas informações ainda são preliminares.
#
# ### Dicionário de Variáveis
#
# * `iso_code` - ISO 3166-1 alfa-3 - códigos de países de três letras
#
# * `continent` - Continente da localização geográfica
#
# * `location` - Localização geográfica
#
# * `date` - Data de observação
#
# * `total_cases` - Total de casos confirmados de COVID-19
#
# * `new_cases` - Novos casos confirmados de COVID-19
#
# * `new_cases_smoothed` - Novos casos confirmados de COVID-19 (7 dias suavizados)
#
# * `total_deaths` - 	Total de mortes atribuídas à COVID-19
#
# * `new_deaths` - Novas mortes atribuídas à COVID-19
#
# * `new_deaths_smoothed` - Novas mortes atribuídas à COVID-19 (7 dias suavizados)
#
# * `total_cases_per_million` - Total de casos confirmados de COVID-19 por 1.000.000 de pessoas
#
# * `new_cases_per_million` - Novos casos confirmados de COVID-19 por 1.000.000 de pessoas
#
# * `new_cases_smoothed_per_million` - Novos casos confirmados de COVID-19 (7 dias suavizados) por 1.000.000 de pessoas
#
# * `total_deaths_per_million` - Total de mortes atribuídas à COVID-19 por 1.000.000 de pessoas
#
# * `new_deaths_per_million` - Novas mortes atribuídas à COVID-19 por 1.000.000 de pessoas
#
# * `new_deaths_smoothed_per_million` - Novas mortes atribuídas à COVID-19 (7 dias suavizados) por 1.000.000 de pessoas
#
# * `reproduction_rate` - Estimativa em tempo real da taxa de reprodução efetiva (R) da COVID-19
#
# * `icu_patients` - Número de pacientes COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia
#
# * `icu_patients_per_million` - Número de pacientes COVID-19 em unidades de terapia intensiva (UTIs) em um determinado dia por 1.000.000 de pessoas
#
# * `hosp_patients` - Número de pacientes da COVID-19 no hospital em um determinado dia
#
# * `hosp_patients_per_million` - Número de pacientes COVID-19 no hospital em um determinado dia por 1.000.000 de pessoas
#
# * `weekly_icu_admissions` - Número de pacientes COVID-19 recém admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana
#
# * `weekly_icu_admissions_per_million` - Número de pacientes COVID-19 recém admitidos em unidades de terapia intensiva (UTIs) em uma determinada semana por 1.000.000 de pessoas
#
# * `weekly_hosp_admissions` - Número de pacientes COVID-19 recém admitidos em hospitais em uma determinada semana
#
# * `weekly_hosp_admissions_per_million` - Número de pacientes COVID-19 recém admitidos em hospitais em uma determinada semana por 1.000.000 de pessoas
#
# * `total_tests` - Testes totais para a COVID-19
#
# * `new_tests` - Novos testes para a COVID-19 (apenas calculados para dias consecutivos)
#
# * `total_tests_per_thousand` - Testes totais para COVID-19 por 1.000 pessoas
#
# * `new_tests_per_thousand` - New tests for COVID-19 per 1,000 people
#
# * `new_tests_smoothed` - Novos testes para a COVID-19 (7 dias
# suavizados). Para países que não relatam dados de testes diariamente, assumimos que os testes mudaram igualmente diariamente em quaisquer períodos em que não foram relatados dados. Isto produz uma série completa de números diários, que é então calculada como média em uma janela rolante de 7 dias.
#
# * `new_tests_smoothed_per_thousand` - Novos testes para COVID-19 (7 dias suavizados) por 1.000 pessoas
#
# * `positive_rate` - A parte dos testes COVID-19 que são positivos, dada como média móvel de 7 dias (este é o inverso dos `tests_per_case`)
#
# * `tests_per_case` - Testes realizados por novo caso confirmado de COVID-19, dado como uma média móvel de 7 dias (este é o inverso de `positive_rate`)
#
# * `tests_units` - Unidades utilizadas pelo local para relatar seus dados de teste
#
# * `total_vaccinations` - Número total de doses de vacinação COVID-19 administradas
#
# * `people_vaccinated` - Número total de pessoas que receberam pelo menos uma dose de vacina
#
# * `people_fully_vaccinated` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação
#
# * `new_vaccinations` - Novas doses de vacinação COVID-19 administradas (apenas calculadas para dias consecutivos)
#
# * `new_vaccinations_smoothed` - Novas doses de vacinação COVID-19 administradas (7 dias suavizadas). Para países que não reportam dados de vacinação diariamente, assumimos que a vacinação mudou igualmente diariamente durante quaisquer períodos em que não foram reportados dados. Isto produz uma série completa de números diários, que é então calculada como média em uma janela rolante de 7 dias.
#
# * `total_vaccinations_per_hundred` - Número total de doses de vacinação COVID-19 administradas por 100 pessoas na população total
#
# * `people_vaccinated_per_hundred` - Número total de pessoas que receberam pelo menos uma dose de vacina por 100 pessoas na população total
#
# * `people_fully_vaccinated_per_hundred` - Número total de pessoas que receberam todas as doses prescritas pelo protocolo de vacinação por 100 pessoas na população total
#
# * `new_vaccinations_smoothed_per_million` - Novas doses de vacinação COVID-19 administradas (7 dias suavizadas) por 1.000.000 de pessoas na população total
#
# * `stringency_index` - Índice de Estringência de Resposta do Governo: medida composta baseada em 9 indicadores de resposta, incluindo fechamento de escolas, fechamento de locais de trabalho e proibição de viagens, redimensionada para um valor de 0 a 100 (100 = resposta mais estrita)
#
# * `population` - Population in 2020
#
# * `population_density` - Número de pessoas dividido por área de terreno, medido em quilômetros quadrados, ano mais recente disponível
#
# * `median_age` - Idade média da população, projeção da ONU para 2020
#
# * `aged_65_older` - Parte da população com 65 anos de idade ou mais, ano mais recente disponível
#
# * `aged_70_older` - Participação da população com 70 anos de idade ou mais em 2015
#
# * `gdp_per_capita` - Produto interno bruto em paridade de poder de compra (dólar internacional constante em 2011), ano mais recente disponível
#
# * `extreme_poverty` - Participação da população vivendo em extrema pobreza, ano mais recente disponível desde 2010
#
# * `cardiovasc_death_rate` - Taxa de mortalidade por doença cardiovascular em 2017 (número anual de mortes por 100.000 pessoas)
#
# * `diabetes_prevalence` - Prevalência do diabetes (% da população de 20 a 79 anos de idade) em 2017
#
# * `female_smokers` - Participação de mulheres que fumam, ano mais recente disponível
#
# * `male_smokers` - Participação de homens que fumam, ano mais recente disponível
#
# * `handwashing_facilities` - Parte da população com instalações básicas de lavagem de mãos nas instalações, o ano mais recente disponível
#
# * `hospital_beds_per_thousand` - Leitos hospitalares por 1.000 pessoas, o ano mais recente disponível desde 2010
#
# * `life_expectancy` - Expectativa de vida ao nascer em 2019
#
# * `human_development_index` - Um índice composto que mede o desempenho médio em três dimensões básicas do desenvolvimento humano - uma vida longa e saudável, conhecimento e um padrão de vida decente.

# %% [markdown]
# ### Importando os dados do COVID-19
#
# Iremos importar os dados e as Bibliotecas necessárias para a análise.

# %%
# importar as bibliotecas necessárias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# importar o dataset COVID-19 para um DataaFrame
df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

df.head()
# Out:
#   iso_code continent  ... human_development_index excess_mortality
# 0      AFG      Asia  ...                   0.511              NaN
# 1      AFG      Asia  ...                   0.511              NaN
# 2      AFG      Asia  ...                   0.511              NaN
# 3      AFG      Asia  ...                   0.511              NaN
# 4      AFG      Asia  ...                   0.511              NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Análise Exploratória dos Dados

# %% [markdown]
# Nessa etapa do projeto buscaremos o maior entendimento possível, de forma que os insights sejam de fácil compreensão e absorção.
#
# Conhecer o corpo do nosso DataFrame é fundamental, então vamos descobrir como estão distribuídos nossos dados.
#
# Com uma linha de código extraímos duas informações importantes:
#
# *   112660 Entradas
# *   62 Colunas

# %%
# tamanho do dataframe
print('O DataFrame possui {} entradas e {} colunas.'.format(df.shape[0], df.shape[1]))
# Out:
# O DataFrame possui 116565 entradas e 62 colunas.

# %% [markdown]
# ### Análise Inicial

# %% [markdown]
# Agora vamos dar uma olhada nas suas 5 primeiras entradas.

# %%
# visualização das 5 primeiras linhas
df.head()
# Out:
#   iso_code continent  ... human_development_index excess_mortality
# 0      AFG      Asia  ...                   0.511              NaN
# 1      AFG      Asia  ...                   0.511              NaN
# 2      AFG      Asia  ...                   0.511              NaN
# 3      AFG      Asia  ...                   0.511              NaN
# 4      AFG      Asia  ...                   0.511              NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# Podemos notar que alguns valores estão faltando, ao decorrer dessa análise vamos ver quais as possibilidades para lidar com eles.

# %% [markdown]
# **Colunas**

# %% [markdown]
# Aqui podemos ver o nome de todas as colunas presentes no DataFrame, e logo no início do projeto é possível encontrar o dicionário para melhor entendimento.

# %%
# nos retorna todas as colunas presentes
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# **Tipos de Dados**

# %% [markdown]
# Em seguida, vamos averiguar quais são os tipos de dados presentes no DataFrame, e por que essa informação é importante?
# Essa informação se torna importante na hora da sua limpeza e mais pra frente nós veremos isso detalhadamente.

# %%
# os tipos das variáveis
df.dtypes
# Out:
# iso_code                       object
# continent                      object
# location                       object
# date                           object
# total_cases                   float64
#                                ...
# handwashing_facilities        float64
# hospital_beds_per_thousand    float64
# life_expectancy               float64
# human_development_index       float64
# excess_mortality              float64
# Length: 62, dtype: object

# %% [markdown]
# ### Valores Ausentes

# %%
# porcentagem de valores ausentes das colunas
(df.isnull().sum()/ df.shape[0]).sort_values(ascending=False)
# Out:
# weekly_icu_admissions_per_million     0.990194
# weekly_icu_admissions                 0.990194
# total_boosters                        0.983752
# total_boosters_per_hundred            0.983752
# weekly_hosp_admissions_per_million    0.982593
#                                         ...
# continent                             0.045768
# population                            0.006855
# date                                  0.000000
# location                              0.000000
# iso_code                              0.000000
# Length: 62, dtype: float64

# %% [markdown]
# #### Tratamento dos Dados Ausentes
#
# Pode-se observar a presença de dados ausentes, vamos analisar cada ma das variáveis que possuem uma grande quantidade de valores faltantes e definir o tratamento mais adequado.
#
# Podemos tirar algumas conclusões:
#
#
# * `total_boosters` `total_boosters_per_hundred`, `weekly_icu_admissions_per_million`, `weekly_icu_admissions`, `weekly_hosp_admissions_per_million` - são variáveis irrelevantes uma vez que quase 97% dos seus valores estão ausentes e por isso podem ser excluídas.

# %% [markdown]
# **Removendo Variáveis**
#
# As variáveis citadas acima serão removidas.

# %%
# Criando cópia do DataFrame
df_clean = df.copy()

# Removendo as Variáveis
df_clean = df_clean.drop(['total_boosters', 'total_boosters_per_hundred', 
                          'weekly_icu_admissions_per_million', 'weekly_icu_admissions', 
                          'weekly_hosp_admissions_per_million'], axis=1)

# Checando corpo do DataFrame após a exclusão
print('Número de colunas antes da exclusão {}'. format(df.shape[1]))
print('Número de colunas após a exclusão {}'.format(df_clean.shape[1]))
# Out:
# Número de colunas antes da exclusão 62
# Número de colunas após a exclusão 57

# %% [markdown]
# Podemos ver que o DataFrame teve uma mudança considerável, de 62 colunas foi para 57 colunas.

# %% [markdown]
# ## Visualização dos Dados
#
# Nessa parte iremos visulizar os dados, seja por meio de gráficos ou por meio do próprio DataFrame.

# %% [markdown]
# **Países com mais casos de Covid-19**
#
# Nessa seção iremos descobrir quais países possuem mais casos de covid para a data de 28 de Agosto de 2021.
#
# Para que possamos ver apenas os 5 países com mais casos, uma lista `continentes` será criada.

# %%
# criação da lista com nome dos continentes
continentes = ['Europe', 'Asia', 'North America', 'South America', 'Oceania', 'Africa', 'European Union',]

# analisar a data mais atual e os 5 países com mais casos 
df_clean.loc[~df_clean.location.isin(continentes)][df_clean.date == '2021-08-28'].sort_values(by='total_cases', ascending=False)[0:6]
# Out:
#         iso_code      continent  ... human_development_index excess_mortality
# 114938  OWID_WRL            NaN  ...                   0.737              NaN
# 111063       USA  North America  ...                   0.926              NaN
# 48779        IND           Asia  ...                   0.645              NaN
# 15433        BRA  South America  ...                   0.765              NaN
# 38302        FRA         Europe  ...                   0.901              NaN
# 87117        RUS         Europe  ...                   0.824              NaN
#
# [6 rows x 57 columns]

# %% [markdown]
# Podemos notar que os países que mais possuem casos, em ordem, são:
#
# * **Mundo** - **215.986.748** casos registrados no Mundo todo.
#
# 1. **Estados Unidos** - **38.760.363** casos registrados, um dos possíveis motivos pela grande quantidade de casos foi também a falha do governo americano em agir de forma rápida e decisiva para evitar a disseminação do vírus.
#
# 2. **India** - **32.695.030** casos registrados, um País com uma população gigantesca, cerca de 1.366 bilhões de pessoas. Apesar de ser um país com um território menor, possui uma elevada densidade demográfica, o que explicaria a quantidade de casos.
#
# 3. **Brazil** - **20.728.605** casos registrados, aqui também temos um País com dimensões continentais, mas uma população menor que a da India e dos Estados Unidos, a quantidade de casos elevados se deve por falta de preparo, pela negligência da população, em relação ao lockdown e o uso de máscaras o que resultou em uma grande disseminação do vírus.
#
# 4. **França** - **6.813.516** casos registrados, um dos grandes motivos para a grande quantidade de casos foi a demora para o o governo agir, gerando uma disseminação ainda maior do vírus.
#
# 5. **Russia** - **6.766.667** casos registrados, um país de dimensões continentais, mas com uma população menor do que a de Países de dimensões parecidas, porém possui um clima favorável para a disseminação do vírus. Entretanto, não se encaixa nos 5 países com mais mortes, o que é um ponto extremamente positivo.

# %% [markdown]
# **Países com mais Mortes**
#
# A seguir vamos descobrir quais países possuem mais mortes para a data 28 de Agosto de 2021.

# %%
# mais mortes
df_clean.loc[~df_clean.location.isin(continentes)][df_clean.date == '2021-04-27'].sort_values(by='total_deaths', ascending=False)[0:6]
# Out:
#         iso_code      continent  ... human_development_index excess_mortality
# 114815  OWID_WRL            NaN  ...                   0.737              NaN
# 110940       USA  North America  ...                   0.926              NaN
# 15310        BRA  South America  ...                   0.765              NaN
# 68262        MEX  North America  ...                   0.779              NaN
# 48656        IND           Asia  ...                   0.645              NaN
# 83463        PER  South America  ...                   0.777              NaN
#
# [6 rows x 57 columns]

# %% [markdown]
# Podemos notar que os países que mais possuem mortes, em ordem, são:
#
# * **Mundo** - **3.242.803** mortes registradas no Mundo todo.
#
# 1. **Estados Unidos** - **573.499** mortes registradas, era de se esperar, o país com mais casos também é o com mais mortes.
#
# 2. **Brasil** - **395.022** mortes registradas, não é o segundo País com mais casos mas é o segundo com mais mortes, possivelmente pela falta de recursos e o despreparo do País para lidar com o vírus.
#
# 3. **Mexico** - **215.547** mortes registradas, aqui temos um caso inesperado, não se encaixa nos 5 países com mais casos, mas está entre os 5 com mais mortes.
#
# 4. **India** - **201.187** mortes registradas, está em segundo com a quantidade de casos, mas em quarto na quantidade de mortes, ao que parece a India soube lidar com o vírus de forma eficiente, para que houvesse um número reduzido de mortos.
#
# 5. **Peru** - **164.433** mortes registradas, não chega a aparecer entre os 5 países com mais casos, mas é um dos 5 com mais mortos, definitivamente é um caso curioso.

# %% [markdown]
# ### Gráfico dos 5 países com mais mortes e casos de Covid-19
#
# Visualizações gráficas são extremamente eficientes se comparadas às informações de um texto. Na próxima célula iremos pltar gráficos para os 5 países com mais mortes e casos.

# %%
top5_total_deaths = df.loc[~df.location.isin(continentes)][df.date == '2021-08-28'].sort_values(by="total_deaths", ascending=False)[1:6]
top5_casos = df.loc[~df.location.isin(continentes)][df.date == '2021-08-28'].sort_values(by="total_cases", ascending=False)[1:6]

fig, (ax0, ax1) = plt.subplots(nrows= 1, ncols=2, figsize=(16, 7))
width = [0.5,0.5,0.5,0.5,0.5]

ax0.bar('location', 'total_deaths', width=width, color=(0.2, 0.4, 0.6, 0.6), data=top5_total_deaths)

ax0.text(0, 900000, "Mortos por Covid-19", color = '#4F4F4F', fontsize=24, fontweight='bold')
ax0.text(0, 700000,'Gráfico para melhor visualização do número de mortos \npelo vírus Coronavírus ao redor do Mundo \nao decorrer do ano de 2019/20.', fontsize=15, color='#808080', fontweight='bold')

ax0.set_xlabel("País")
ax0.set_ylabel("Número de mortes")
ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)

ax1.bar('location', 'total_cases', width=width, color=(0.2, 0.4, 0.6, 0.6), data=top5_casos)

ax1.text(0, 55000000, "Casos de Covid-19", color = '#4F4F4F', fontsize=24, fontweight='bold')
ax1.text(0, 43000000,'Gráfico para melhor visualização do número de casos \npelo vírus Coronavírus ao redor do Mundo \nao decorrer do ano de 2019/20.', fontsize=15, color='#808080', fontweight='bold')


ax1.set_xlabel("País")
ax1.set_ylabel("Número de casos")
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

plt.tight_layout();
fig.savefig("graf_barra1_mortes_casos.png")

# %% [markdown]
# O gráfico comprova as tabelas acima e nos mostra de forma mais clara o número de mortes e casos.
#
# Quando falamos da quantidade total de mortes, temos 3.242.803 mortes no mundo e 215.986.748 casos, cerca de **1,5%** das pessoas que contraíram o vírus *morreram*, enquanto **98,5% se recuperaram**.

# %% [markdown]
# ## Gráfico de mortes e casos ao decorrer do tempo
#
# A seguir, plotarei um gráfico para que seja possível ver a evolução dos casos e mortes de Covid-19 ao decorrer do tempo.

# %%
# gráfico de linhas 2
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(16, 12))

# gráfico 1
df.loc[df.location == "United States", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Estados Unidos")
df.loc[df.location == "Brazil", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Brasil")
df.loc[df.location == "United Kingdom", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Reino Unido")
df.loc[df.location == "Italy", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label= "Itália")
df.loc[df.location == "France", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="França")

ax0.text(-7, 1450000, "Mortos por Covid-19", color = '#4F4F4F', fontsize=24, fontweight='bold')
ax0.text(-7, 1180000,'Gráfico para melhor visualização do número de mortos \npelo vírus Coronavírus ao redor do Mundo \nao decorrer do ano de 2019/20.', fontsize=15, color='#808080', fontweight='bold')

ax0.set_ylim(0, 1000000)
ax0.set_xlabel("Data")
ax0.set_ylabel("Nº Mortes")
ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax0.set_xticklabels(labels=df.date)
ax0.set_yticklabels(labels=[], visible=False)
ax0.set_yticks(ticks=[])


ax0.legend();

# gráfico 2 
df.loc[df.location == "United States", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Estados Unidos")
df.loc[df.location == "India", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Índia")
df.loc[df.location == "Brazil", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Brasil")
df.loc[df.location == "France", "total_cases"].reset_index(drop=True).plot(ax=ax1, label= "França")
df.loc[df.location == "Russia", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Rússia")

ax1.text(-30, 60000000, "Casos de Covid-19", color = '#4F4F4F', fontsize=24, fontweight='bold')
ax1.text(-30, 50000000,'Número de casos pelo Coronavírus ao redor do mundo \nem relação ao decorrer do tempo.', fontsize=15, color='#808080', fontweight='bold')

ax1.set_xlabel("Data")
ax1.set_ylabel("Nº Casos")
ax1.legend(loc='right')
ax1.legend();
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.set_xticklabels(labels=df.date)
ax1.set_yticklabels(labels=[], visible=False)
ax1.set_yticks(ticks=[])



plt.tight_layout();
fig.savefig("graf_linhas_mortes_casos.png")

# %% [markdown]
# Alguns insights que o gráfico nos mostra com clareza:
#
#
#
# * Apesar dos Estados Unidos terem se mantido na frente durante grande parte do tempo, só em determinado tempo o número de casos deu um salto realmente expressivo.
# *  A Índia se manteve na frente no número de casos em relação ao Brasil, mas o Brasil possui muito mais número de mortes.
# * Países como a Reino Unido, Itália e França possuem os números de mortes bem próximos. Enquanto que no quesito número de casos o único que se mantem entre os 5 primeiros é a França.

# %% [markdown]
# ### Análise Exploratória para o Brasil
#
# Agora iremos fazer uma análise específica para o Brasil, farei uma cópia do DataFrame que irá me retornar entradas apenas do Brasil como localização.
#
# Vamos ver esse dataset e observar as 5 primeiras entradas.

# %%
# criando a cópia do dataframe para o Brasil
df_brasil = df.loc[df.location == "Brazil"].copy()

# exibindo as 5 entradas iniciais
df_brasil.head()
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 14884      BRA  South America  ...                   0.765              NaN
# 14885      BRA  South America  ...                   0.765              NaN
# 14886      BRA  South America  ...                   0.765              NaN
# 14887      BRA  South America  ...                   0.765             9.91
# 14888      BRA  South America  ...                   0.765              NaN
#
# [5 rows x 62 columns]

# %% [markdown]
# **Data mais recente**
#
# Agora iremos analisar a data mais recente do nosso dataset e assim saberemos a linha cronológica dos dados.

# %%
# a última entada do dataframe
df_brasil.date.max()
# Out:
# '2021-09-13'

# %% [markdown]
# **Primeira Morte no Brasil**
#
# Essa parte considero extremamente importante, visto que todo o início do Covid no Brasil ainda é um enigma.

# %%
# data da primeira morte
df_brasil.loc[df_brasil['new_deaths'] == 1.0].head(1)
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 14904      BRA  South America  ...                   0.765              NaN
#
# [1 rows x 62 columns]

# %% [markdown]
# A data da primeira morte no Brasil foi registrada no dia **17 de Março de 2020** e nesse mesmo dia o Brasil já tinha *321 casos confirmados*.

# %% [markdown]
# **Primeiro Caso no Brasil**
#
# Com certeza você lembra do dilema no Carnaval de 2020. Ninguém sabia se teria ou não, ninguém sabia se existia um caso confirmado ou não no Brasil.
#
# Agora iremos saber quando foi o primeiro caso confirmado no Brasil.

# %%
# primeiro caso
df_brasil.loc[df_brasil['new_cases'] !=0.0].head(1)
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 14884      BRA  South America  ...                   0.765              NaN
#
# [1 rows x 62 columns]

# %% [markdown]
# Primeiro caso de Covid-19 foi no dia **26 de Março de 2020**.

# %% [markdown]
# ### Covid no Brasil e América do Sul
#
# O Brasil sem sombra de dúvidas foi um dos Países que mais sofreu com a pandemia do Coronavírus e para fins de comparação, iremos fazer uma análise do Brasil em comparação aos 5 Países com mais casos e mais mortes da **América Do Sul**.
#
# Para isso vamos criar uma cópia do **DataFrame** onde estarão presentes apenas entradas que o continente seja a América do Sul. Vamos conhecer o *dataset* olhando as 5 primeiras entradas.

# %%
# criando uma cópia do dataframe apenas com os dados da américa do sul
df_southAmerica = df_clean.loc[df_clean.continent == 'South America'].copy()

# checar as 5 primeiras entradas
df_southAmerica.head()
# Out:
#      iso_code      continent  ... human_development_index excess_mortality
# 4154      ARG  South America  ...                   0.845              NaN
# 4155      ARG  South America  ...                   0.845              NaN
# 4156      ARG  South America  ...                   0.845              NaN
# 4157      ARG  South America  ...                   0.845              NaN
# 4158      ARG  South America  ...                   0.845              NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# **Países com mais casos de Covid-19**
#
# Em seguida, iremos localizar quais países da América do Sul possuem mais casos para a data mais atual.

# %%
# países da américa do sul com mais casos
df_southAmerica.loc[df_southAmerica.date =='2021-08-28'].sort_values(by='total_cases', 
                                                                     ascending=False)[0:5]
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 15433      BRA  South America  ...                   0.765              NaN
# 4759       ARG  South America  ...                   0.845              NaN
# 23105      COL  South America  ...                   0.767              NaN
# 83586      PER  South America  ...                   0.777              NaN
# 21947      CHL  South America  ...                   0.851              NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# Os Países que mais possuem casos, em ordem, são:
#
# * **Brasil** - **20.728.605** casos registrados.
#
# * **Argentina** - **5.171.458** casos resgistrados
#
# * **Colômbia** - **4.903.304** casos registrados
#
# * **Peru** - **2.143.691** casos registrados
#
# * **Chile** - **1.637.234** casos registrados
#
# É notável a diferença do número de casos do Brasil quando comparado aos outros países. Se torna um dado assustador quando descobrimos que, apenas os casos do Brasil, representam mais de **50% de todos os casos da América do Sul**.

# %% [markdown]
# **Países com Mais Mortes**
#
# Por fim, vamos localizar quais Países da América do Sul possuem mais mortes para a data mais atual.

# %%
# países da américa do sul com mais mortes
df_southAmerica.loc[df_southAmerica.date =='2021-08-28'].sort_values(by='total_deaths', 
                                                                     ascending=False)[0:5]
# Out:
#       iso_code      continent  ... human_development_index excess_mortality
# 15433      BRA  South America  ...                   0.765              NaN
# 83586      PER  South America  ...                   0.777              NaN
# 23105      COL  South America  ...                   0.767              NaN
# 4759       ARG  South America  ...                   0.845              NaN
# 21947      CHL  South America  ...                   0.851              NaN
#
# [5 rows x 57 columns]

# %% [markdown]
# Os países que mais possuem mortes, em ordem, são:
#
# * **Brasil** - **579.010** mortes registradas.
#
# * **Peru** - **198.031** mortes registradas.
#
# * **Colômbia** - **124.743** mortes registradas.
#
# * **Argentina** - **111.324** mortes registradas.
#
# * **Chile** - **36.841** mortes registradas.
#
# Portanto, aqui vemos mais uma vez que o Brasil se mantém liderando a quantidade de mortes, assim como os casos. Entretanto, a **Argentina** possui mais casos que a **Colômbia**, mas possui menos mortes.

# %% [markdown]
# **Os 5 países com mais Mortes e Casos de Covid-19 - Gráficos**
#
# A seguir plotaremos gráficos para visualizarmos a disposição dos casos e das mortes nos Países da América do Sul.

# %%
mortes_america = df_southAmerica.loc[df_southAmerica.date == '2021-08-28', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[0:5]
casos_america = df_southAmerica.loc[df_southAmerica.date == '2021-08-28', ['location', 'total_cases']].sort_values(by="total_cases", ascending=False)[0:5]

fig, (ax0, ax1) = plt.subplots(nrows= 1, ncols=2, figsize=(16, 7))

ax0.bar('location', 'total_deaths',  width=width, color=(0.2, 0.4, 0.6, 0.6), data=mortes_america)

ax0.text(0, 740000, "Mortos na América do Sul", color = '#4F4F4F', fontsize=24, fontweight='bold')
ax0.text(0, 630000,'Gráfico para melhor visualização do número de mortos \npelo vírus Coronavírus na América do Sul \nao decorrer do ano de 2019/20.', fontsize=15, color='#808080', fontweight='bold')

ax0.set_xlabel("País")
ax0.set_ylabel("Número de mortes")
ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)

ax1.bar('location', 'total_cases',  width=width, color=(0.2, 0.4, 0.6, 0.6), data=casos_america)

ax1.text(0, 26500000, "Casos de Covid-19", color = '#4F4F4F', fontsize=24, fontweight='bold')
ax1.text(0, 22500000,'Gráfico para melhor visualização do número de casos \npelo vírus Coronavírus na América do Sul \nao decorrer do ano de 2019/20.', fontsize=15, color='#808080', fontweight='bold')

ax1.set_xlabel("País")
ax1.set_ylabel("Número de casos")
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)

plt.tight_layout();
fig.savefig("graf_barra2_mortes_casos.png")

# %% [markdown]
# Podemos observar algumas coisas nos gráficos:
#
# * O **Brasil** representa a maior parte dos *casos* e das *mortes* na América do Sul.
# * Apesar da **Argentina** ter maior número de casos ela possui *menor número* de **mortes** comparada à Colômbia.

# %%
# gráfico de linhas 
fig, (ax0, ax1) = plt.subplots(2, 1, figsize=(16, 12))

# gráfico 1 
df.loc[df.location == "Brazil", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Brasil")
df.loc[df.location == "Peru", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Peru")
df.loc[df.location == "Colombia", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Colombia")
df.loc[df.location == "Argentina", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label= "Argentina")
df.loc[df.location == "Chile", "total_deaths"].reset_index(drop=True).plot(ax=ax0, label="Chile")

ax0.text(-13, 900000, "Mortos América do Sul", color = '#4F4F4F', fontsize=25, fontweight='bold')
ax0.text(-13, 750000,'Número de mortos pelo Covid-19 na América do Sul \nem relação ao tempo decorrido \ndos anos de 2019/20', fontsize=15, color='#808080', fontweight='bold')

ax0.set_xlabel("Data")
ax0.set_ylabel("Nº Mortes")
ax0.spines['right'].set_visible(False)
ax0.spines['top'].set_visible(False)
ax0.set_xticklabels(labels=df.date)
ax0.set_yticklabels(labels=[], visible=False)
ax0.set_yticks(ticks=[])
ax0.legend();


# gráfico 2 
df.loc[df.location == "Brazil", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Brasil")
df.loc[df.location == "Argentina", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Argentina")
df.loc[df.location == "Colombia", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Colômbia")
df.loc[df.location == "Peru", "total_cases"].reset_index(drop=True).plot(ax=ax1, label= "Peru")
df.loc[df.location == "Chile", "total_cases"].reset_index(drop=True).plot(ax=ax1, label="Chile")

ax1.text(-30, 31000000, "Casos América do Sul", color = '#4F4F4F', fontsize=25, fontweight='bold')
ax1.text(-30, 25500000,'Número de casos de Covid-19 na América do Sul \nem relação ao tempo decorrido \ndos anos de 2019/20', fontsize=15, color='#808080', fontweight='bold')


ax1.set_xlabel("Data")
ax1.set_ylabel("Nº Casos")
ax1.legend(loc='right')
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.set_xticklabels(labels=df.date)
ax1.set_yticklabels(labels=[], visible=False)
ax1.set_yticks(ticks=[])
ax1.legend();

plt.tight_layout();
fig.savefig("graf_linhas2_mortes_casos.png")

# %% [markdown]
# ## Rio de Janeiro
# ### Toda a cidade se mantém em alto risco devido à circulação de variante
#
# <center><img alt="Colaboratory logo" width="70%" src="https://raw.githubusercontent.com/brunavent/template_temp/master/rio.jpg"></center>
#
#
# Mais de **60 mil pessoas** já morreram de covid-19 no Estado do Rio de Janeiro. Com as 121 mortes registradas pela Secretaria Estadual de Saúde nos últimos 7 dias, o número total de mortos pela doença no Estado desde o início da pandemia chegou a 1 milhão e 130 mil mortes.

# %% [markdown]
# ### Wordcloud
#
# Agora iremos criar uma wordcloud usando a biblioteca wordcloud.
# WordCloud são ótimas se deseja que seu público responda com uma ou duas palavras, ou para enfatizar palavras mais populares ou comuns. O ideal é que as respostas sejam curtas.
#
# <p align=center><img src="https://raw.githubusercontent.com/brunavent/template_temp/master/rio_covid_wordcloud.png" width="430px"></p>
#
# Importaremos novos dados do Rio Saúde para nosso wordcloud.

# %%
# instalando o wordcloud
# !pip install wordcloud -q

# %%
# importando os pacotes
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# importando o arquivo csv
file = ("db_PainelRioCovid.csv")
df = pd.read_csv(file)

# eliminando as colunas de valores ausentes na coluna que nos interessa
bairro_resid_estadia = df.dropna(subset=['bairro_resid_estadia'], axis=0)['bairro_resid_estadia']

# %%
df.head()
# Out:
#   classificação_final  dt_notific  ... Data_atualizacao sistema
# 0          CONFIRMADO  06/11/2020  ...       18/08/2021   SIVEP
# 1          CONFIRMADO  10/14/2020  ...       18/08/2021   SIVEP
# 2          CONFIRMADO  11/30/2020  ...       18/08/2021   SIVEP
# 3          CONFIRMADO  12/15/2020  ...       18/08/2021   SIVEP
# 4          CONFIRMADO  12/04/2020  ...       18/08/2021   SIVEP
#
# [5 rows x 12 columns]

# %%
# ver a quantidade de valores ausentes
print("Valores ausentes para Bairro: ", df.bairro_resid_estadia.isnull().sum())

# eliminar as colunas com valores ausentes
bairro_resid_estadia = df.dropna(subset=['bairro_resid_estadia'], axis=0)['bairro_resid_estadia']
# Out:
# Valores ausentes para Bairro:  0

# %% [markdown]
# **Agora iremos concatenar todas as 427.124 palavras extraídas da base de dados.**

# %%
all_bairro_resid_estadia = "  ".join(s for s in bairro_resid_estadia)

print("Quantidade de Palavras: {}".format(len(bairro_resid_estadia)))
# Out:
# Quantidade de Palavras: 427124

# %% [markdown]
# Plotaremos uma primeira versão "bruta" para visualizarmos as palavras e observarmos se algo pode ser refinado nessa wordcloud.

# %%
stopwords = set(STOPWORDS)

wordcloud = WordCloud(stopwords=stopwords,
                      background_color="black").generate(all_bairro_resid_estadia)

fig, ax = plt.subplots(figsize=(10, 6))
ax.imshow(wordcloud, interpolation='bilinear')

plt.tight_layout();
wordcloud.to_file("rio1_covid_wordcloud.png")

# %% [markdown]
# Agora:
# 1.   Criaremos uma lista de `stopwords`, que são palavras que deveriam ser removidas, pode ser artigos, pronomes... Nesse caso a palavra `ignorado` aparece de forma desnecessária na plotagem final, então iremos removê-la.
# 2.   Iremos instanciar um objeto do tipo `WordCloud` e iremos fornecer os parâmetros necessários.

# %%
# lista de stopword
stopwords = set(STOPWORDS)
stopwords.update(["Ignorado"])

# gerando a wordcloud
wordcloud = WordCloud(stopwords=stopwords, 
                      background_color="black",
                      width=1600, height=800).generate(all_bairro_resid_estadia)

# imagem final
fig, ax = plt.subplots(figsize=(16,8))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.imshow(wordcloud);

wordcloud.to_file("rio2_covid_wordcloud.png")

# %% [markdown]
# Surpresos por Campo Grande ser o bairro com mais mortes e casos de Covid-19?
# De acordo com dados da Prefeitura do Rio, divulgados através do Painel Rio Covid-19, o bairro de Campo Grande lidera no número de casos e na quantidade de mortes pelo novo coronavírus na cidade. Ao todo, são mais de 20.000 casos confirmados e 2.000 mortes.

# %% [markdown]
# Aproveitei que a WordCloud me fornece ferramentas que brincam com a visualização e coloquei os bairros com mais casos e mortes em uma imagem do Cristo Redentor.

# %%
# endereço da imagem do cristo
rio_mask = np.array(Image.open("/content/Cristo_Redentor_Rio_De_Janeiro_silhouettes__Best_Places_in_Brazil.vector_illustration_design.jpg"))

# gerando a wordcloud
wordcloud = WordCloud(stopwords=stopwords,
                      background_color="black",
                      width=1200, height=1200, max_words=2000,
                      mask=rio_mask, max_font_size=200,
                      min_font_size=1).generate(all_bairro_resid_estadia)


# plotagem da imagem final
fig, ax = plt.subplots(figsize=(15, 12))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()

plt.imshow(wordcloud);
wordcloud.to_file("rio_covid_wordcloud.png")

# %% [markdown]
# ## Conclusão
#
# Vamos falar dos *insights* que podemos retirar dessa análise.
#
# * O **Estados Unidos** é de longe o País com mais casos e mortes.
#
# * O **Brasil** é o segundo País com mais mortes.
#
# * Não é por ter mais casos que também terão mais mortes e vice-versa, exemplos disso são a **Índia** e o **Brasil**.
#
# * A **Índia** possui mais casos que o **Brasil** mas possui menos mortes.
#
# * O Brasil é o País da América do Sul que mais sofreu com a Pandemia.
#
# ### Rio de Janeiro
#
# No Rio de Janeiro temos **Campo Grande** como o bairro mais prejudicado pela pandemia. Bairros como Barra da Tijuca, Santa Cruz, Tijuca e Recreio dos Bandeirantes também aparecem com certa notoriedade na nossa WordCloud.
#
# E, infelizmente, os impactos sociais, econômicos, culturais e políticos da pandemia são irreversíveis tanto no Brasil como um todo, como no Rio de Janeiro.
# O que nos resta é acreditar que o amanhã será melhor.
